# %%
# Import Dependencies
import pandas as pd
from pathlib import Path
import json
import matplotlib.pyplot as plt

# %%
# Make a reference to the Chicago_Energy_Benchmarking_20240408.csv file path
csv_path = Path("Chicago_Energy_Benchmarking_20240408.csv")

# Import the Chicago_Energy_Benchmarking_202404.csv file as a DataFrame
df = pd.read_csv(csv_path, encoding="utf-8")

# Check the data imported correctly
df.head()
# Out:
#    Data Year      ID              Property Name Reporting Status  \
# 0       2020  252064           Mansueto Library   Submitted Data
# 1       2020  232458  Harper Square Cooperative   Submitted Data
# 2       2020  254616       Former Coyne College   Submitted Data
# 3       2020  103812          400 W Superior St   Submitted Data
# 4       2020  254073            Blue Moon Lofts   Submitted Data
#
#                        Address ZIP Code  Chicago Energy Rating  \
# 0               1100 E 57th St    60637                    2.0
# 1  4800 - 4850 S Lake Park Ave    60615                    1.0
# 2               330 N Green St    60607                    2.0
# 3            400 W Superior St    60654                    3.0
# 4          215 N. Aberdeen St.    60607                    4.0
#
#   Exempt From Chicago Energy Rating   Community Area Primary Property Type  \
# 0                             False        HYDE PARK               Library
# 1                             False          KENWOOD   Multifamily Housing
# 2                             False   NEAR WEST SIDE                Office
# 3                             False  NEAR NORTH SIDE                Office
# 4                             False   NEAR WEST SIDE   Multifamily Housing
#
#    ...  Site EUI (kBtu/sq ft)  Source EUI (kBtu/sq ft)  \
# 0  ...                  240.8                    323.6
# 1  ...                   95.5                    146.0
# 2  ...                   55.5                    148.3
# 3  ...                   61.4                    151.8
# 4  ...                   29.4                     64.9
#
#    Weather Normalized Site EUI (kBtu/sq ft)  \
# 0                                     246.0
# 1                                     100.3
# 2                                      56.7
# 3                                      63.0
# 4                                      29.6
#
#    Weather Normalized Source EUI (kBtu/sq ft)  \
# 0                                       329.9
# 1                                       150.7
# 2                                       151.8
# 3                                       154.8
# 4                                        64.3
#
#    Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# 0                                  1160.9                           18.1
# 1                                  4871.7                            7.8
# 2                                  4581.4                            8.2
# 3                                  1092.1                            8.4
# 4                                   295.8                            3.6
#
#     Latitude  Longitude                     Location       Row_ID
# 0  41.792213 -87.599950  (41.79221307, -87.59994981)  2020-252064
# 1  41.807475 -87.591264  (41.80747487, -87.59126397)  2020-232458
# 2  41.873335 -87.651021    (41.873335, -87.65102071)  2020-254616
# 3  41.895752 -87.638901    (41.89575232, -87.638901)  2020-103812
# 4  41.874295 -87.650175  (41.87429514, -87.65017516)  2020-254073
#
# [5 rows x 30 columns]

# %%
min_year= df['Data Year'].min()
max_year= df['Data Year'].max()
print(min_year)
print(max_year)
# Out:
# 2014
# 2022

# %%
min_rate= df['Chicago Energy Rating'].min()
max_rate= df['Chicago Energy Rating'].max()
print(min_rate)
print(max_rate)
# Out:
# 0.0
# 4.0

# %%
df_22= df[df['Data Year'] == 2022]
df_20= df[df['Data Year'] == 2020]
df_18= df[df['Data Year'] == 2018]
df_16= df[df['Data Year'] == 2016]

# %%
exemptdf= df[df['Exempt From Chicago Energy Rating']== False]
exempt= exemptdf.drop_duplicates(subset= ['Address'])
cleaned= exempt.dropna(subset=['Electricity Use (kBtu)','Site EUI (kBtu/sq ft)' ])
q1= cleaned['Site EUI (kBtu/sq ft)'].quantile(0.25)
q3= cleaned['Site EUI (kBtu/sq ft)'].quantile(0.75)

iq= q3- q1

low= q1- 1.5*iq
high= q3+ 1.5 *iq

filter = cleaned[(cleaned['Site EUI (kBtu/sq ft)'] >= low) & (cleaned['Site EUI (kBtu/sq ft)'] <= high)]

reduced_df = filter[["Data Year", "ID", "Property Name", "Address", "Chicago Energy Rating", "Exempt From Chicago Energy Rating",
"Community Area", "Primary Property Type", "Gross Floor Area - Buildings (sq ft)", "Year Built", "Electricity Use (kBtu)",
 "Natural Gas Use (kBtu)","Site EUI (kBtu/sq ft)", "Source EUI (kBtu/sq ft)", "Weather Normalized Site EUI (kBtu/sq ft)",
 "Weather Normalized Source EUI (kBtu/sq ft)", "Total GHG Emissions (Metric Tons CO2e)", "GHG Intensity (kg CO2e/sq ft)", 
 "Latitude", "Longitude"]]
reduced_df.head()
# Out:
#    Data Year      ID                                 Property Name  \
# 1       2020  232458                     Harper Square Cooperative
# 2       2020  254616                          Former Coyne College
# 3       2020  103812                             400 W Superior St
# 4       2020  254073                               Blue Moon Lofts
# 5       2020  254385  Ambulatory Care Center, St. Bernard Hospital
#
#                        Address  Chicago Energy Rating  \
# 1  4800 - 4850 S Lake Park Ave                    1.0
# 2               330 N Green St                    2.0
# 3            400 W Superior St                    3.0
# 4          215 N. Aberdeen St.                    4.0
# 5           6307 S STEWART AVE                    2.5
#
#   Exempt From Chicago Energy Rating   Community Area Primary Property Type  \
# 1                             False          KENWOOD   Multifamily Housing
# 2                             False   NEAR WEST SIDE                Office
# 3                             False  NEAR NORTH SIDE                Office
# 4                             False   NEAR WEST SIDE   Multifamily Housing
# 5                             False        Englewood        Medical Office
#
#    Gross Floor Area - Buildings (sq ft)  Year Built  Electricity Use (kBtu)  \
# 1                              627680.0      1974.0              16397682.8
# 2                              555524.0      2019.0              28606427.7
# 3                              130007.0      1998.0               6489281.3
# 4                               83000.0      1908.0               1614582.3
# 5                               98018.0      2016.0               4204723.5
#
#    Natural Gas Use (kBtu)  Site EUI (kBtu/sq ft)  Source EUI (kBtu/sq ft)  \
# 1              43537490.6                   95.5                    146.0
# 2               2199940.1                   55.5                    148.3
# 3               1493523.2                   61.4                    151.8
# 4                825006.6                   29.4                     64.9
# 5               2236782.3                   96.7                    211.9
#
#    Weather Normalized Site EUI (kBtu/sq ft)  \
# 1                                     100.3
# 2                                      56.7
# 3                                      63.0
# 4                                      29.6
# 5                                      98.0
#
#    Weather Normalized Source EUI (kBtu/sq ft)  \
# 1                                       150.7
# 2                                       151.8
# 3                                       154.8
# 4                                        64.3
# 5                                       212.8
#
#    Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# 1                                  4871.7                            7.8
# 2                                  4581.4                            8.2
# 3                                  1092.1                            8.4
# 4                                   295.8                            3.6
# 5                                   775.0                           11.6
#
#     Latitude  Longitude
# 1  41.807475 -87.591264
# 2  41.873335 -87.651021
# 3  41.895752 -87.638901
# 4  41.874295 -87.650175
# 5  41.773912 -87.638721

# %%
exempt22_df= df_22[df_22['Exempt From Chicago Energy Rating']== False]
exempt20_df= df_20[df_20['Exempt From Chicago Energy Rating']== False]
exempt18_df= df_18[df_18['Exempt From Chicago Energy Rating']== False]
exempt16_df= df_16[df_16['Exempt From Chicago Energy Rating']== False]
print(len(df_18))
# Out:
# 3430

# %%
import seaborn as sns

# %%
NumReporting = {"DataYear":[2016, 2018, 2020,2022],
                "Buildings":[len(df_16),len(exempt18_df),len(exempt20_df),len(exempt22_df)]}
NumReporting
df_Reporting = pd.DataFrame(NumReporting)
sns.set_theme(style="darkgrid")
sns.lineplot(x=df_Reporting["DataYear"], y=df_Reporting["Buildings"], marker ='o', linewidth = 3)

plt.savefig("Output\Buildings.png")
# Out:
# c:\Users\mrkol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\mrkol\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# NumReporting = [
#     {2022: {"Buildings": [len(exempt22_df)]}},
#     {2020: {"Buildings": [len(exempt20_df)]}},
#     {2018: {"Buildings": [len(exempt18_df)]}},
#     {2016: {"Buildings": [len(df_16)]}}
# ]
#
#
# print(NumReporting)
# df_Reporting = pd.DataFrame(NumReporting)
# df_Reporting
# test = df_Reporting.to_json()
# print(test)

# %%
exempt22= exempt22_df.drop_duplicates(subset= ['Address'])
exempt20= exempt20_df.drop_duplicates(subset= ['Address'])
exempt18= exempt18_df.drop_duplicates(subset= ['Address'])
exempt16= exempt16_df.drop_duplicates(subset= ['Address'])
exempt20
# Out:
#       Data Year      ID                  Property Name Reporting Status  \
# 0          2020  252064               Mansueto Library   Submitted Data
# 1          2020  232458      Harper Square Cooperative   Submitted Data
# 2          2020  254616           Former Coyne College   Submitted Data
# 3          2020  103812              400 W Superior St   Submitted Data
# 4          2020  254073                Blue Moon Lofts   Submitted Data
# ...         ...     ...                            ...              ...
# 3578       2020  254174                            NaN   Submitted Data
# 3579       2020  251529         Lovett Elementary -CPS   Submitted Data
# 3580       2020  250114  Zelda Ormes Senior Apartments   Submitted Data
# 3581       2020  171887                            NaN   Submitted Data
# 3582       2020  166134          John G Shedd Aquarium   Submitted Data
#
#                           Address ZIP Code  Chicago Energy Rating  \
# 0                  1100 E 57th St    60637                    2.0
# 1     4800 - 4850 S Lake Park Ave    60615                    1.0
# 2                  330 N Green St    60607                    2.0
# 3               400 W Superior St    60654                    3.0
# 4             215 N. Aberdeen St.    60607                    4.0
# ...                           ...      ...                    ...
# 3578          4200 W Diversey Ave    60639                    3.0
# 3579      6333 W Bloomingdale Ave    60639                    4.0
# 3580                 116 W Elm St    60610                    4.0
# 3581         1824 N SPAULDING AVE    60647                    4.0
# 3582         1200 S Lake Shore Dr    60605                    1.0
#
#      Exempt From Chicago Energy Rating   Community Area Primary Property Type  \
# 0                                False        HYDE PARK               Library
# 1                                False          KENWOOD   Multifamily Housing
# 2                                False   NEAR WEST SIDE                Office
# 3                                False  NEAR NORTH SIDE                Office
# 4                                False   NEAR WEST SIDE   Multifamily Housing
# ...                                ...              ...                   ...
# 3578                             False          Hermosa                 Other
# 3579                             False           AUSTIN           K-12 School
# 3580                             False  NEAR NORTH SIDE   Multifamily Housing
# 3581                             False     LOGAN SQUARE   Multifamily Housing
# 3582                             False  NEAR SOUTH SIDE                 Other
#
#       ...  Site EUI (kBtu/sq ft)  Source EUI (kBtu/sq ft)  \
# 0     ...                  240.8                    323.6
# 1     ...                   95.5                    146.0
# 2     ...                   55.5                    148.3
# 3     ...                   61.4                    151.8
# 4     ...                   29.4                     64.9
# ...   ...                    ...                      ...
# 3578  ...                   64.0                    106.7
# 3579  ...                   73.8                    101.5
# 3580  ...                   85.2                    124.1
# 3581  ...                   63.0                     95.6
# 3582  ...                  183.9                    402.1
#
#       Weather Normalized Site EUI (kBtu/sq ft)  \
# 0                                        246.0
# 1                                        100.3
# 2                                         56.7
# 3                                         63.0
# 4                                         29.6
# ...                                        ...
# 3578                                      68.7
# 3579                                      78.9
# 3580                                      87.9
# 3581                                      67.2
# 3582                                     186.7
#
#       Weather Normalized Source EUI (kBtu/sq ft)  \
# 0                                          329.9
# 1                                          150.7
# 2                                          151.8
# 3                                          154.8
# 4                                           64.3
# ...                                          ...
# 3578                                       112.9
# 3579                                       106.9
# 3580                                       125.9
# 3581                                        99.3
# 3582                                       405.0
#
#       Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# 0                                     1160.9                           18.1
# 1                                     4871.7                            7.8
# 2                                     4581.4                            8.2
# 3                                     1092.1                            8.4
# 4                                      295.8                            3.6
# ...                                      ...                            ...
# 3578                                   807.5                            5.7
# 3579                                   454.5                            5.3
# 3580                                  1045.5                            6.6
# 3581                                   330.1                            5.1
# 3582                                  9988.9                           22.1
#
#        Latitude  Longitude                     Location       Row_ID
# 0     41.792213 -87.599950  (41.79221307, -87.59994981)  2020-252064
# 1     41.807475 -87.591264  (41.80747487, -87.59126397)  2020-232458
# 2     41.873335 -87.651021    (41.873335, -87.65102071)  2020-254616
# 3     41.895752 -87.638901    (41.89575232, -87.638901)  2020-103812
# 4     41.874295 -87.650175  (41.87429514, -87.65017516)  2020-254073
# ...         ...        ...                          ...          ...
# 3578  41.920398 -87.756200       (41.9203976, -87.7562)  2020-254174
# 3579  41.912786 -87.783130       (41.912786, -87.78313)  2020-251529
# 3580  41.903163 -87.631828      (41.903163, -87.631828)  2020-250114
# 3581  41.920750 -87.701528  (41.92075046, -87.70152825)  2020-171887
# 3582  41.867615 -87.613630  (41.86761516, -87.61362973)  2020-166134
#
# [3405 rows x 30 columns]

# %%
cleaned22= exempt22.dropna(subset=['Electricity Use (kBtu)','Site EUI (kBtu/sq ft)' ])
cleaned20= exempt20.dropna(subset=['Electricity Use (kBtu)','Site EUI (kBtu/sq ft)' ])
cleaned18= exempt18.dropna(subset=['Electricity Use (kBtu)','Site EUI (kBtu/sq ft)' ])

cleaned18
# Out:
#        Data Year      ID                                 Property Name  \
# 3602        2018  101420                              Chicago Acad-CPS
# 3606        2018  160414                                 Cambria Hotel
# 3611        2018  173625                                   Burnham 600
# 3619        2018  175603  Gateway Centre 175603 Building A (Marshalls)
# 3620        2018  251684                               Marine Lead-CPS
# ...          ...     ...                                           ...
# 14356       2018  156876                              Newberry Library
# 14357       2018  149143             The Residences at 950 West Monroe
# 14362       2018  255191                                Anatomy/Culver
# 14363       2018  101871                                  123 N Wacker
# 14370       2018  251905                               FunstonFred-CPS
#
#       Reporting Status                  Address ZIP Code  \
# 3602         Submitted        3400 N Austin Ave    60634
# 3606         Submitted            32 w randolph    60601
# 3611         Submitted     600 W. Jackson Blvd.    60661
# 3619         Submitted      1701-1741 W. Howard    60626
# 3620         Submitted        1920 N Hamlin Ave    60647
# ...                ...                      ...      ...
# 14356        Submitted             60 W. Walton    60610
# 14357        Submitted          950 W Monroe St    60607
# 14362        Submitted    1027 East 57th Street    60637
# 14363        Submitted             123 N Wacker    60606
# 14370        Submitted  2010 N Central Park Ave    60647
#
#        Chicago Energy Rating Exempt From Chicago Energy Rating  \
# 3602                     2.0                             False
# 3606                     4.0                             False
# 3611                     4.0                             False
# 3619                     1.0                             False
# 3620                     2.5                             False
# ...                      ...                               ...
# 14356                    2.0                             False
# 14357                    2.5                             False
# 14362                    1.0                             False
# 14363                    3.0                             False
# 14370                    1.5                             False
#
#         Community Area Primary Property Type  ...  Site EUI (kBtu/sq ft)  \
# 3602           DUNNING           K-12 School  ...                   96.6
# 3606              LOOP                 Hotel  ...                   52.9
# 3611    NEAR WEST SIDE                Office  ...                  104.0
# 3619       ROGERS PARK            Strip Mall  ...                  310.1
# 3620      LOGAN SQUARE           K-12 School  ...                   71.4
# ...                ...                   ...  ...                    ...
# 14356  NEAR NORTH SIDE               Library  ...                   95.9
# 14357   NEAR WEST SIDE   Multifamily Housing  ...                   81.8
# 14362        Hyde Park            Laboratory  ...                  388.6
# 14363             LOOP                Office  ...                   50.7
# 14370     LOGAN SQUARE           K-12 School  ...                   81.7
#
#        Source EUI (kBtu/sq ft)  Weather Normalized Site EUI (kBtu/sq ft)  \
# 3602                     149.2                                      95.1
# 3606                      97.2                                      53.1
# 3611                     175.9                                     101.5
# 3619                     719.4                                     312.3
# 3620                     135.1                                      69.8
# ...                        ...                                       ...
# 14356                    167.5                                      95.8
# 14357                    142.8                                      81.3
# 14362                    560.8                                     377.7
# 14363                    142.1                                      50.7
# 14370                    133.8                                      81.3
#
#        Weather Normalized Source EUI (kBtu/sq ft)  \
# 3602                                        146.6
# 3606                                         97.3
# 3611                                        173.2
# 3619                                        721.8
# 3620                                        133.3
# ...                                           ...
# 14356                                       167.4
# 14357                                       141.4
# 14362                                       549.2
# 14363                                       142.1
# 14370                                       133.4
#
#        Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# 3602                                   2062.6                            8.2
# 3606                                   1355.4                            5.5
# 3611                                   1022.3                            9.8
# 3619                                   2797.5                           42.0
# 3620                                    972.0                            7.7
# ...                                       ...                            ...
# 14356                                  1884.0                            9.4
# 14357                                   990.7                            8.0
# 14362                                  2140.1                           31.9
# 14363                                  4962.5                            8.4
# 14370                                   802.1                            7.4
#
#         Latitude  Longitude                     Location       Row_ID
# 3602   41.942538 -87.777370  (41.94253753, -87.77737003)  2018-101420
# 3606   41.885040 -87.628996  (41.88503972, -87.62899559)  2018-160414
# 3611   41.878018 -87.643191  (41.87801775, -87.64319149)  2018-173625
# 3619   42.019356 -87.673890       (42.019356, -87.67389)  2018-175603
# 3620   41.915982 -87.722486   (41.9159824, -87.72248643)  2018-251684
# ...          ...        ...                          ...          ...
# 14356  41.900020 -87.630608  (41.90002028, -87.63060779)  2018-156876
# 14357  41.873994 -87.651678    (41.87399385, -87.651678)  2018-149143
# 14362  41.783986 -87.615539    (41.7839855, -87.6155392)  2018-255191
# 14363  41.884120 -87.636497  (41.88411984, -87.63649725)  2018-101871
# 14370  41.917749 -87.717127  (41.91774866, -87.71712677)  2018-251905
#
# [2737 rows x 30 columns]

# %%
q122= cleaned22['Site EUI (kBtu/sq ft)'].quantile(0.25)
q322= cleaned22['Site EUI (kBtu/sq ft)'].quantile(0.75)

iq22= q322- q122

low22= q122- 1.5*iq22
high22= q322+ 1.5 *iq22

filter22 = cleaned22[(cleaned22['Site EUI (kBtu/sq ft)'] >= low22) & (cleaned22['Site EUI (kBtu/sq ft)'] <= high22)]

# %%
q120= cleaned20['Site EUI (kBtu/sq ft)'].quantile(0.25)
q320= cleaned20['Site EUI (kBtu/sq ft)'].quantile(0.75)

iq20= q320- q120

low20= q120- 1.5*iq20
high20= q320+ 1.5 *iq20

filter20 = cleaned20[(cleaned20['Site EUI (kBtu/sq ft)'] >= low20) & (cleaned20['Site EUI (kBtu/sq ft)'] <= high20)]
q118= cleaned18['Site EUI (kBtu/sq ft)'].quantile(0.25)
q318= cleaned18['Site EUI (kBtu/sq ft)'].quantile(0.75)

iq18= q318- q118

low18= q118- 1.5*iq18
high18= q318+ 1.5 *iq18

filter18 = cleaned18[(cleaned18['Site EUI (kBtu/sq ft)'] >= low18) & (cleaned18['Site EUI (kBtu/sq ft)'] <= high18)]

filter18
# Out:
#        Data Year      ID                      Property Name Reporting Status  \
# 3602        2018  101420                   Chicago Acad-CPS        Submitted
# 3606        2018  160414                      Cambria Hotel        Submitted
# 3611        2018  173625                        Burnham 600        Submitted
# 3620        2018  251684                    Marine Lead-CPS        Submitted
# 3626        2018  251223                  564 West Randolph        Submitted
# ...          ...     ...                                ...              ...
# 14353       2018  254051                     NewCity Retail        Submitted
# 14356       2018  156876                   Newberry Library        Submitted
# 14357       2018  149143  The Residences at 950 West Monroe        Submitted
# 14363       2018  101871                       123 N Wacker        Submitted
# 14370       2018  251905                    FunstonFred-CPS        Submitted
#
#                         Address ZIP Code  Chicago Energy Rating  \
# 3602          3400 N Austin Ave    60634                    2.0
# 3606              32 w randolph    60601                    4.0
# 3611       600 W. Jackson Blvd.    60661                    4.0
# 3620          1920 N Hamlin Ave    60647                    2.5
# 3626   564 West Randolph Street    60661                    4.0
# ...                         ...      ...                    ...
# 14353         1457 N Halsted St    60642                    2.0
# 14356              60 W. Walton    60610                    2.0
# 14357           950 W Monroe St    60607                    2.5
# 14363              123 N Wacker    60606                    3.0
# 14370   2010 N Central Park Ave    60647                    1.5
#
#       Exempt From Chicago Energy Rating   Community Area  \
# 3602                              False          DUNNING
# 3606                              False             LOOP
# 3611                              False   NEAR WEST SIDE
# 3620                              False     LOGAN SQUARE
# 3626                              False   NEAR WEST SIDE
# ...                                 ...              ...
# 14353                             False  Near North Side
# 14356                             False  NEAR NORTH SIDE
# 14357                             False   NEAR WEST SIDE
# 14363                             False             LOOP
# 14370                             False     LOGAN SQUARE
#
#       Primary Property Type  ...  Site EUI (kBtu/sq ft)  \
# 3602            K-12 School  ...                   96.6
# 3606                  Hotel  ...                   52.9
# 3611                 Office  ...                  104.0
# 3620            K-12 School  ...                   71.4
# 3626                 Office  ...                   98.1
# ...                     ...  ...                    ...
# 14353                 Other  ...                  109.8
# 14356               Library  ...                   95.9
# 14357   Multifamily Housing  ...                   81.8
# 14363                Office  ...                   50.7
# 14370           K-12 School  ...                   81.7
#
#        Source EUI (kBtu/sq ft)  Weather Normalized Site EUI (kBtu/sq ft)  \
# 3602                     149.2                                      95.1
# 3606                      97.2                                      53.1
# 3611                     175.9                                     101.5
# 3620                     135.1                                      69.8
# 3626                     192.8                                      98.1
# ...                        ...                                       ...
# 14353                    271.1                                     108.8
# 14356                    167.5                                      95.8
# 14357                    142.8                                      81.3
# 14363                    142.1                                      50.7
# 14370                    133.8                                      81.3
#
#        Weather Normalized Source EUI (kBtu/sq ft)  \
# 3602                                        146.6
# 3606                                         97.3
# 3611                                        173.2
# 3620                                        133.3
# 3626                                        192.8
# ...                                           ...
# 14353                                       270.1
# 14356                                       167.4
# 14357                                       141.4
# 14363                                       142.1
# 14370                                       133.4
#
#        Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# 3602                                   2062.6                            8.2
# 3606                                   1355.4                            5.5
# 3611                                   1022.3                            9.8
# 3620                                    972.0                            7.7
# 3626                                   1320.6                           11.0
# ...                                       ...                            ...
# 14353                                 10807.7                           15.9
# 14356                                  1884.0                            9.4
# 14357                                   990.7                            8.0
# 14363                                  4962.5                            8.4
# 14370                                   802.1                            7.4
#
#         Latitude  Longitude                     Location       Row_ID
# 3602   41.942538 -87.777370  (41.94253753, -87.77737003)  2018-101420
# 3606   41.885040 -87.628996  (41.88503972, -87.62899559)  2018-160414
# 3611   41.878018 -87.643191  (41.87801775, -87.64319149)  2018-173625
# 3620   41.915982 -87.722486   (41.9159824, -87.72248643)  2018-251684
# 3626   41.884638 -87.642325  (41.88463844, -87.64232477)  2018-251223
# ...          ...        ...                          ...          ...
# 14353  41.903838 -87.636680      (41.9038385, -87.63668)  2018-254051
# 14356  41.900020 -87.630608  (41.90002028, -87.63060779)  2018-156876
# 14357  41.873994 -87.651678    (41.87399385, -87.651678)  2018-149143
# 14363  41.884120 -87.636497  (41.88411984, -87.63649725)  2018-101871
# 14370  41.917749 -87.717127  (41.91774866, -87.71712677)  2018-251905
#
# [2550 rows x 30 columns]
